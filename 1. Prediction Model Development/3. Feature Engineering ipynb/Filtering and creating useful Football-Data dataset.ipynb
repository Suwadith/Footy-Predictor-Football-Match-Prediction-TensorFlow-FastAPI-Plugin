# %% [markdown]
# ### Combining all "Football-Data" seasonal datasets

# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
files = os.path.join("C:\\Users\\suwad\\OneDrive - Middlesex University\\Desktop\\MDX\Modules\\8. CST4444 Individual Project\\06. Rsearch Datasets\\Source\\3. Football-Data\\1. EPL Seasonal Match Stats\\", "*.csv")

# list of merged files returned
files = glob.glob(files)

# joining files with concat and read_csv
pd.set_option('display.max_columns', None)
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df
# Out:
#      Div  Season        Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  \
# 0     E0      11  13/08/2011       Blackburn       Wolves     1     2   A
# 1     E0      11  13/08/2011          Fulham  Aston Villa     0     0   D
# 2     E0      11  13/08/2011       Liverpool   Sunderland     1     1   D
# 3     E0      11  13/08/2011       Newcastle      Arsenal     0     0   D
# 4     E0      11  13/08/2011             QPR       Bolton     0     4   A
# ...   ..     ...         ...             ...          ...   ...   ...  ..
# 4175  E0      21  22/05/2022  Crystal Palace   Man United     1     0   H
# 4176  E0      21  22/05/2022       Leicester  Southampton     4     1   H
# 4177  E0      21  22/05/2022       Liverpool       Wolves     3     1   H
# 4178  E0      21  22/05/2022        Man City  Aston Villa     3     2   H
# 4179  E0      21  22/05/2022         Norwich    Tottenham     0     5   A
#
#       HTHG  HTAG HTR     Referee  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  \
# ...

# %% [markdown]
# ### Selecting useful metrics for future macth prediction
# #### Appropriate match data & Bookies data (odds)

# %%
# Date = Match Date (dd/mm/yy)
# FTHG - Full Time Home Team Goals
# FTAG - Full Time Away Team Goals
# FTR - Full Time Result
# HS = Home Team Shots
# AS = Away Team Shots
# HST = Home Team Shots on Target
# AST = Away Team Shots on Target
# HY - Home Team Yellow Cards
# AY - Away Team Yellow Cards
# HR - Home Team Red Cards
# AR - Away Team Red Cards
# B365H - Bet365 home win odds
# B365D - Bet365 draw odds
# B365A - Bet365 away win odds
# BWH - Bet&Win home win odds
# BWD - Bet&Win draw odds
# BWA - Bet&Win away win odds
# IWH - Interwetten home win odds
# IWD - Interwetten draw odds
# IWA - Interwetten away win odds
# SYH - Stanleybet home win odds
# SYD - Stanleybet draw odds
# SYA - Stanleybet away win odds
# VCH - VC Bet home win odds
# VCD - VC Bet draw odds
# VCA - VC Bet away win odds


new_df = df.loc[:, df.columns.isin(['Date', 'Season', 'HomeTeam', 'AwayTeam', 
                           'FTHG', 'FTAG', 'FTR',
                           'HS', 'AS', 'HST', 'AST', 
                           'HY', 'AY', 'HR', 'AR',
                           'B365H', 'B365D', 'B365A', 
                           'BWH', 'BWD', 'BWA', 
                           'IWH', 'IWD', 'IWA', 
                           'SYH', 'SYD', 'SYA', 
                           'VCH', 'VCD', 'VCA'])]
new_df
# Out:
#       Season        Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  \
# 0         11  13/08/2011       Blackburn       Wolves     1     2   A  16  13
# 1         11  13/08/2011          Fulham  Aston Villa     0     0   D  13   7
# 2         11  13/08/2011       Liverpool   Sunderland     1     1   D  11  15
# 3         11  13/08/2011       Newcastle      Arsenal     0     0   D   6   9
# 4         11  13/08/2011             QPR       Bolton     0     4   A  13  13
# ...      ...         ...             ...          ...   ...   ...  ..  ..  ..
# 4175      21  22/05/2022  Crystal Palace   Man United     1     0   H   6  10
# 4176      21  22/05/2022       Leicester  Southampton     4     1   H  12   7
# 4177      21  22/05/2022       Liverpool       Wolves     3     1   H  29   7
# 4178      21  22/05/2022        Man City  Aston Villa     3     2   H  24   4
# 4179      21  22/05/2022         Norwich    Tottenham     0     5   A   9  19
#
# ...

# %% [markdown]
# ### Storing the new Dataframe

# %%
new_df.to_csv(r'C:\Users\suwad\OneDrive - Middlesex University\Desktop\MDX\Modules\8. CST4444 Individual Project\06. Rsearch Datasets\Processed\Football-Data.csv', sep=',', index=False, encoding='utf-8')
