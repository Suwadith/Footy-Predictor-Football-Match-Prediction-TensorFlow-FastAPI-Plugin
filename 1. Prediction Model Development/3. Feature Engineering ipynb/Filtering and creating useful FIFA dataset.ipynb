# %% [markdown]
# ### Combining all "FIFA Player Ratings" seasonal datasets

# %%
import pandas as pd
import glob
import os

# setting the path for joining multiple files
files = os.path.join("C:\\Users\\suwad\\OneDrive - Middlesex University\\Desktop\\MDX\Modules\\8. CST4444 Individual Project\\06. Rsearch Datasets\\Source\\2. FIFA\\1. Player Stats 2015-2022\\", "*.csv")

# list of merged files returned
files = glob.glob(files)

# joining files with concat and read_csv
pd.set_option('display.max_columns', None)
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
df
# Out:
# C:\Users\suwad\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:294: DtypeWarning: Columns (105) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
# C:\Users\suwad\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:294: DtypeWarning: Columns (82,83,84,85,86) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
# C:\Users\suwad\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:294: DtypeWarning: Columns (26,109) have mixed types.Specify dtype option on import or set low_memory=False.
#   op = _Concatenator(
#         sofifa_id                                         player_url  season  \
# 0          158023  https://sofifa.com/player/158023/lionel-messi/...      15
# 1           20801  https://sofifa.com/player/20801/c-ronaldo-dos-...      15
# 2            9014  https://sofifa.com/player/9014/arjen-robben/15...      15
# ...

# %%
new_df = df.loc[df['league_name'] == "English Premier League"]
new_df
# Out:
#         sofifa_id                                         player_url  season  \
# 7            7826  https://sofifa.com/player/7826/robin-van-persi...      15
# 10         167397  https://sofifa.com/player/167397/radamel-falca...      15
# 11         183277  https://sofifa.com/player/183277/eden-hazard/1...      15
# 15         168542  https://sofifa.com/player/168542/david-josue-j...      15
# 20          20289  https://sofifa.com/player/20289/yaya-toure/150002      15
# ...           ...                                                ...     ...
# 141282     240866  https://sofifa.com/player/240866/reece-hannam/...      22
# 141350     256556  https://sofifa.com/player/256556/ben-chrisene/...      22
# 141532     251516  https://sofifa.com/player/251516/ossama-ashley...      22
# 141717     244507  https://sofifa.com/player/244507/pascal-juan-e...      22
# 141718     245130  https://sofifa.com/player/245130/oliver-webber...      22
#
# ...

# %%
new_df = new_df.loc[:, new_df.columns.isin(['season', 'long_name', 'player_positions', 
                                    'overall', 'value_eur', 'wage_eur', 'age',
                                    'club_name', 'league_name', 'international_reputation', 
                                    'pace', 'shooting', 'passing', 'dribbling', 'physic'])]
new_df
# Out:
#         season                     long_name player_positions  overall  \
# 7           15              Robin van Persie               ST       88
# 10          15  Radamel Falcao García Zárate               ST       88
# 11          15                   Eden Hazard           LM, RM       88
# 15          15     David Josué Jiménez Silva          LM, CAM       87
# 20          15           Gnégnéri Yaya Touré          CM, CDM       86
# ...        ...                           ...              ...      ...
# 141282      22                  Reece Hannam               LB       53
# 141350      22                  Ben Chrisene          LB, LWB       53
# 141532      22                 Ossama Ashley               CM       52
# 141717      22           Pascal Juan Estrada           CB, CM       51
# 141718      22                 Oliver Webber               GK       51
#
#          value_eur  wage_eur  age                club_name  \
# ...

# %%
grouped_df = new_df.groupby(['club_name', 'season'])[['overall', 'age', 'value_eur', 'wage_eur', 
                                        'international_reputation', 'pace', 'shooting', 
                                        'passing', 'dribbling', 'physic']].sum()
grouped_df
# Out:
#                                 overall  age    value_eur   wage_eur  \
# club_name               season
# AFC Bournemouth         16         2027  748   62720000.0   619000.0
#                         17         2279  796   98785000.0   990000.0
#                         18         2315  821  137030000.0  1276000.0
#                         19         2311  812  151895000.0  1119000.0
#                         20         2386  817  214700000.0  1277000.0
# ...                                 ...  ...          ...        ...
# West Ham United         22         2382  863  365755000.0  1449500.0
# Wolverhampton Wanderers 19         2346  800  178925000.0  1153000.0
#                         20         2325  784  231550000.0  1422000.0
#                         21         2298  783  317625000.0  1332000.0
#                         22         2298  779  321580000.0  1422000.0
#
#                                 international_reputation    pace  shooting  \
# ...

# %%
reset_df = grouped_df.reset_index()
reset_df
# Out:
#                    club_name  season  overall  age    value_eur   wage_eur  \
# 0            AFC Bournemouth      16     2027  748   62720000.0   619000.0
# 1            AFC Bournemouth      17     2279  796   98785000.0   990000.0
# 2            AFC Bournemouth      18     2315  821  137030000.0  1276000.0
# 3            AFC Bournemouth      19     2311  812  151895000.0  1119000.0
# 4            AFC Bournemouth      20     2386  817  214700000.0  1277000.0
# ..                       ...     ...      ...  ...          ...        ...
# 155          West Ham United      22     2382  863  365755000.0  1449500.0
# 156  Wolverhampton Wanderers      19     2346  800  178925000.0  1153000.0
# 157  Wolverhampton Wanderers      20     2325  784  231550000.0  1422000.0
# 158  Wolverhampton Wanderers      21     2298  783  317625000.0  1332000.0
# 159  Wolverhampton Wanderers      22     2298  779  321580000.0  1422000.0
#
# ...

# %%
reset_df.loc[reset_df['season'] == 15, 'season'] = 14
reset_df.loc[reset_df['season'] == 16, 'season'] = 15
reset_df.loc[reset_df['season'] == 17, 'season'] = 16
reset_df.loc[reset_df['season'] == 18, 'season'] = 17
reset_df.loc[reset_df['season'] == 19, 'season'] = 18
reset_df.loc[reset_df['season'] == 20, 'season'] = 19
reset_df.loc[reset_df['season'] == 21, 'season'] = 20
reset_df.loc[reset_df['season'] == 22, 'season'] = 21

# %%
reset_df
# Out:
#                    club_name  season  overall  age    value_eur   wage_eur  \
# 0            AFC Bournemouth      15     2027  748   62720000.0   619000.0
# 1            AFC Bournemouth      16     2279  796   98785000.0   990000.0
# 2            AFC Bournemouth      17     2315  821  137030000.0  1276000.0
# 3            AFC Bournemouth      18     2311  812  151895000.0  1119000.0
# 4            AFC Bournemouth      19     2386  817  214700000.0  1277000.0
# ..                       ...     ...      ...  ...          ...        ...
# 155          West Ham United      21     2382  863  365755000.0  1449500.0
# 156  Wolverhampton Wanderers      18     2346  800  178925000.0  1153000.0
# 157  Wolverhampton Wanderers      19     2325  784  231550000.0  1422000.0
# 158  Wolverhampton Wanderers      20     2298  783  317625000.0  1332000.0
# 159  Wolverhampton Wanderers      21     2298  779  321580000.0  1422000.0
#
# ...

# %%
reset_df.to_csv(r'C:\Users\suwad\OneDrive - Middlesex University\Desktop\MDX\Modules\8. CST4444 Individual Project\06. Rsearch Datasets\Processed\FIFA.csv', sep=',', index=False, encoding='utf-8')
