# %%
import pandas as pd

Football_Data_df= pd.read_csv (r'C:\Users\suwad\OneDrive - Middlesex University\Desktop\MDX\Modules\8. CST4444 Individual Project\06. Rsearch Datasets\Processed\Football-Data.csv')
FBRef_df = pd.read_csv (r'C:\Users\suwad\OneDrive - Middlesex University\Desktop\MDX\Modules\8. CST4444 Individual Project\06. Rsearch Datasets\Processed\FBRef - Final.csv')
FIFA_df= pd.read_csv (r'C:\Users\suwad\OneDrive - Middlesex University\Desktop\MDX\Modules\8. CST4444 Individual Project\06. Rsearch Datasets\Processed\FIFA - Final.csv')

# %%
Football_Data_df.head()
# Out:
#    Season        Date   HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  HST  \
# 0      11  13/08/2011  Blackburn       Wolves     1     2   A  16  13    8
# 1      11  13/08/2011     Fulham  Aston Villa     0     0   D  13   7    9
# 2      11  13/08/2011  Liverpool   Sunderland     1     1   D  11  15    4
# 3      11  13/08/2011  Newcastle      Arsenal     0     0   D   6   9    1
# 4      11  13/08/2011        QPR       Bolton     0     4   A  13  13    7
#
#    ...  B365A   BWH   BWD   BWA  IWH  IWD  IWA   VCH  VCD   VCA
# 0  ...    3.5  2.00  3.30  3.60  2.0  3.3  3.3  2.15  3.4  3.60
# 1  ...    3.5  2.05  3.30  3.45  2.2  3.2  3.0  2.15  3.3  3.75
# 2  ...    7.0  1.45  3.85  7.50  1.4  4.1  7.0  1.53  4.0  7.50
# 3  ...    2.1  3.65  3.25  2.00  3.7  3.3  1.9  3.80  3.4  2.10
# 4  ...    3.0  2.25  3.25  3.05  2.3  3.2  2.8  2.38  3.3  3.30
#
# [5 rows x 27 columns]

# %%
FBRef_df.tail()
# Out:
#       season  week        date       home_team    away_team  attendance  \
# 4690    2122  38.0  2022-05-22  Crystal Palace   Man United     25434.0
# 4691    2122  38.0  2022-05-22       Leicester  Southampton     32003.0
# 4692    2122  38.0  2022-05-22       Liverpool       Wolves     53097.0
# 4693    2122  38.0  2022-05-22        Man City  Aston Villa     53395.0
# 4694    2122  38.0  2022-05-22         Norwich    Tottenham     27022.0
#
#       home_xg  away_xg
# 4690      0.5      0.8
# 4691      2.3      1.2
# 4692      3.2      1.1
# 4693      2.9      0.3
# 4694      0.3      3.7

# %%
FIFA_df.head()
# Out:
#      club_name  season    overall        age     value_eur      wage_eur  \
# 0  Bournemouth      16  69.896552  25.793103  2.240000e+06  21344.827586
# 1  Bournemouth      17  69.060606  24.121212  2.993485e+06  30000.000000
# 2  Bournemouth      18  70.151515  24.878788  4.152424e+06  38666.666667
# 3  Bournemouth      19  70.030303  24.606061  4.602879e+06  33909.090909
# 4  Bournemouth      20  72.303030  24.757576  6.506061e+06  38696.969697
#
#    international_reputation       pace   shooting    passing  dribbling  \
# 0                  1.103448  72.615385  54.192308  61.384615  67.653846
# 1                  1.151515  75.464286  55.678571  60.500000  67.535714
# 2                  1.121212  71.481481  56.074074  60.444444  67.222222
# 3                  1.121212  67.033333  55.333333  61.233333  66.700000
# 4                  1.090909  69.310345  58.206897  65.172414  69.103448
#
#       physic
# 0  68.000000
# 1  66.892857
# 2  66.629630
# 3  63.833333
# 4  67.517241

# %%
Football_Data_df['Date'] = pd.to_datetime(Football_Data_df['Date'])

# %%
FBRef_df['date'] = pd.to_datetime(FBRef_df['date'])

# %%
res = Football_Data_df.merge(FBRef_df, how='inner', 
                             left_on=['Date', 'HomeTeam', 'AwayTeam'], 
                             right_on=['date', 'home_team', 'away_team'])

res
# Out:
#       Season       Date        HomeTeam     AwayTeam  FTHG  FTAG FTR  HS  AS  \
# 0         11 2011-08-13       Blackburn       Wolves     1     2   A  16  13
# 1         11 2011-08-13          Fulham  Aston Villa     0     0   D  13   7
# 2         11 2011-08-13       Liverpool   Sunderland     1     1   D  11  15
# 3         11 2011-08-13       Newcastle      Arsenal     0     0   D   6   9
# 4         11 2011-08-13             QPR       Bolton     0     4   A  13  13
# ...      ...        ...             ...          ...   ...   ...  ..  ..  ..
# 2739      21 2022-05-22  Crystal Palace   Man United     1     0   H   6  10
# 2740      21 2022-05-22       Leicester  Southampton     4     1   H  12   7
# 2741      21 2022-05-22       Liverpool       Wolves     3     1   H  29   7
# 2742      21 2022-05-22        Man City  Aston Villa     3     2   H  24   4
# 2743      21 2022-05-22         Norwich    Tottenham     0     5   A   9  19
#
# ...
