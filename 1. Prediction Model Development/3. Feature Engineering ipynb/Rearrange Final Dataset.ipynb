# %%
import pandas as pd

Final_df= pd.read_csv (r'C:\Users\suwad\OneDrive - Middlesex University\Desktop\MDX\Modules\8. CST4444 Individual Project\06. Rsearch Datasets\Processed\Football-Data+_Football-Data-New-Extended.csv')
pd.set_option('display.max_columns', None)

# %%
Final_df
# Out:
#       Attendance    Away Team  Away Xg        Date FTR       Home Team  \
# 0            NaN       Wolves      NaN  13/08/2011   A       Blackburn
# 1            NaN  Aston Villa      NaN  13/08/2011   D          Fulham
# 2            NaN   Sunderland      NaN  13/08/2011   D       Liverpool
# 3            NaN       Bolton      NaN  13/08/2011   A             QPR
# 4            NaN      Norwich      NaN  13/08/2011   D           Wigan
# ...          ...          ...      ...         ...  ..             ...
# 4099     25434.0   Man United      0.8  22/05/2022   H  Crystal Palace
# 4100     32003.0  Southampton      1.2  22/05/2022   H       Leicester
# 4101     53097.0       Wolves      1.1  22/05/2022   H       Liverpool
# 4102     53395.0  Aston Villa      0.3  22/05/2022   H        Man City
# 4103     27022.0    Tottenham      3.7  22/05/2022   A         Norwich
#
#       Home Xg          Referee               Venue  Week  Home Age  Away Age  \
# ...

# %%
Final_df.columns.values.tolist()
# Out:
# ['Attendance',
#  'Away Team',
#  'Away Xg',
#  'Date',
#  'FTR',
#  'Home Team',
#  'Home Xg',
#  'Referee',
#  'Venue',
#  'Week',
#  'Home Age',
#  'Away Age',
#  'AR',
#  'AS',
#  'AST',
#  'Home Team Attack',
#  'Away Team Attack',
#  'AY',
#  'B365A',
#  'B365D',
#  'B365H',
#  'BWA',
#  'BWD',
#  'BWH',
#  'Home Team Defense',
#  'Away Team Defense',
#  'Home Dribbling',
#  'Away Dribbling',
#  'Ftag',
#  'Fthg',
#  'HR',
#  'HS',
#  'HST',
#  'HY',
#  'Home International Reputation',
#  'Away International Reputation',
#  'IWA',
#  'IWD',
#  'IWH',
#  'Home Team Midfield',
#  'Away Team Midfield',
#  'Home Overall',
#  'Away Overall',
#  'Home Team Overall',
#  'Away Team Overall',
#  'Home Pace',
#  'Away Pace',
#  'Home Passing',
#  'Away Passing',
#  'Home Physic',
#  'Away Physic',
#  'Home Team Rank',
#  'Away Team Rank',
#  'Home Team Rating',
#  'Away Team Rating',
#  'Season',
#  'Home Shooting',
#  'Away Shooting',
#  'Home Value Eur',
#  'Away Value Eur',
#  'VCA',
# ...

# %%
columnsTitles = ['Season', 'Week', 'Date', 'Attendance', 
                 'Referee', 'Venue', 
                 'Home Team', 'Away Team', 
                 'Fthg', 'Ftag', 'FTR',
                 'HS', 'AS', 'HST', 'AST', 
                 'HY', 'AY', 'HR', 'AR',
                 'Home Xg', 'Away Xg',
                 'B365H', 'B365D', 'B365A', 
                 'BWH', 'BWD', 'BWA', 
                 'IWH', 'IWD', 'IWA', 
                 'VCH', 'VCD', 'VCA',
                 'Home Team Attack', 'Away Team Attack',
                 'Home Team Defense', 'Away Team Defense',
                 'Home Team Midfield', 'Away Team Midfield',
                 'Home Team Overall', 'Away Team Overall',
                 'Home Team Rank', 'Away Team Rank',
                 'Home Team Rating', 'Away Team Rating',
                 'Home Overall', 'Away Overall',
                 'Home Age', 'Away Age',
                 'Home Pace', 'Away Pace',
                 'Home Dribbling', 'Away Dribbling',
                 'Home Passing', 'Away Passing',
                 'Home Physic', 'Away Physic',
                 'Home Shooting', 'Away Shooting',
                 'Home Value Eur', 'Away Value Eur',
                 'Home Wage Eur', 'Away Wage Eur',
                 'Home International Reputation', 'Away International Reputation']

Final_df_df = Final_df.reindex(columns=columnsTitles)

# %%
Final_df_df
# Out:
#       Season  Week        Date  Attendance          Referee  \
# 0         11     1  13/08/2011         NaN     Kevin Friend
# 1         11     1  13/08/2011         NaN        Lee Mason
# 2         11     1  13/08/2011         NaN        Phil Dowd
# 3         11     1  13/08/2011         NaN  Martin Atkinson
# 4         11     1  13/08/2011         NaN   Stuart Attwell
# ...      ...   ...         ...         ...              ...
# 4099      21    38  22/05/2022     25434.0  Martin Atkinson
# 4100      21    38  22/05/2022     32003.0    Jonathan Moss
# 4101      21    38  22/05/2022     53097.0   Anthony Taylor
# 4102      21    38  22/05/2022     53395.0   Michael Oliver
# 4103      21    38  22/05/2022     27022.0   Chris Kavanagh
#
#                    Venue       Home Team    Away Team  Fthg  Ftag FTR  HS  AS  \
# 0                    NaN       Blackburn       Wolves     1     2   A  16  13
# 1                    NaN          Fulham  Aston Villa     0     0   D  13   7
# ...

# %%
Final_df_df.to_csv(r'C:\Users\suwad\OneDrive - Middlesex University\Desktop\MDX\Modules\8. CST4444 Individual Project\06. Rsearch Datasets\Processed\Combined-Finalised-New-Extended.csv', sep=',', index=False, encoding='utf-8')
